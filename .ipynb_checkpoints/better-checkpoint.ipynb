# %%
import pandas as pd

data = pd.read_csv('RawData.csv')
data.tail()
# Out:
#                        Date            Name      Team  Season Round Home Team  \
# 146602  2003-03-30 00:00:00     Wayne Carey  Adelaide  2003.0     1  Adelaide
# 146603  2003-03-30 00:00:00    Brett Burton  Adelaide  2003.0     1  Adelaide
# 146604  2003-03-30 00:00:00    Matthew Bode  Adelaide  2003.0     1  Adelaide
# 146605  2003-03-30 00:00:00  Rhett Biglands  Adelaide  2003.0     1  Adelaide
# 146606  2003-03-30 00:00:00    Mark Bickley  Adelaide  2003.0     1  Adelaide
#
#         Away Team  Home Score  Away Score  Margin  ...  Frees For  \
# 146602  Fremantle         145          89      56  ...        1.0
# 146603  Fremantle         145          89      56  ...        0.0
# 146604  Fremantle         145          89      56  ...        1.0
# 146605  Fremantle         145          89      56  ...        1.0
# 146606  Fremantle         145          89      56  ...        1.0
#
#         Frees Against  Contested Pos  Uncontested Pos  Contested Marks  \
# 146602            2.0            9.0              4.0              3.0
# 146603            0.0            9.0             11.0              0.0
# 146604            2.0            9.0             12.0              0.0
# 146605            0.0            3.0              1.0              0.0
# 146606            1.0            7.0             10.0              0.0
#
#         Marks Inside 50  One Percenters  Goal Assists  Brownlow Votes  TOG
# 146602              4.0             4.0           2.0             0.0   85
# 146603              0.0             1.0           0.0             0.0   90
# 146604              0.0             1.0           0.0             0.0   96
# 146605              0.0             1.0           0.0             0.0   47
# 146606              1.0             0.0           3.0             0.0   61
#
# [5 rows x 32 columns]

# %% [markdown]
# # Cleaning

# %%
games = data.drop_duplicates(subset=['Date', 'Home Team', 'Away Team', 'Margin'])[[
   'Date', 'Season', 'Round', 'Home Team', 'Away Team',
       'Home Score', 'Away Score', 'Margin', 
]]
games
# Out:
#                        Date  Season Round       Home Team  \
# 0       2019-09-28 00:00:00  2019.0    GF        Richmond
# 44      2019-09-21 00:00:00  2019.0    PF     Collingwood
# 88      2019-09-20 00:00:00  2019.0    PF         Geelong
# 132     2019-09-14 00:00:00  2019.0    SF  Brisbane Lions
# 176     2019-09-13 00:00:00  2019.0    SF         Geelong
# ...                     ...     ...   ...             ...
# 146388  2003-04-26 00:00:00  2003.0     5        Adelaide
# 146432  2003-04-20 00:00:00  2003.0     4        Adelaide
# 146476  2003-04-13 00:00:00  2003.0     3          Sydney
# 146520  2003-04-05 00:00:00  2003.0     2        St Kilda
# 146564  2003-03-30 00:00:00  2003.0     1        Adelaide
#
#                      Away Team  Home Score  Away Score  Margin
# 0       Greater Western Sydney         114          25      89
# 44      Greater Western Sydney          52          56      -4
# 88                    Richmond          66          85     -19
# 132     Greater Western Sydney          80          83      -3
# 176                 West Coast          88          68      20
# ...                        ...         ...         ...     ...
# 146388           Port Adelaide          66          78     -12
# 146432              West Coast         106          73      33
# 146476                Adelaide          76         103     -27
# 146520                Adelaide          99          91       8
# 146564               Fremantle         145          89      56
#
# [3333 rows x 8 columns]

# %% [markdown]
# We have 3333 games in total (what a cool number). 3151 games have Brownlow votes and 182 of them (5.4%) do not. For simplicity I will removed these games

# %%
# Number of games with votes
data[data['Brownlow Votes'] == 3].shape[0]
# Out:
# 3151

# %%
import numpy as np

def preprocess(data=data):
    """
    Extract Year information
    Set GameID=Day+HomeTeam for each game
    Set Win_True and Win_False columns to tell if the player won that game
    Remove if game doesn't have votes
    """
    data['Year'] = data['Date'].str.extract(r"(\d{4})-*")
    data['Year'] = pd.to_numeric(data['Year'])
    
    data['Day'] = data['Date'].str.extract(r"(\d{4}-\d{2}-\d{2})") 
    
    data['GameID'] = data['Day'] + data['Home Team']
            
    data['Win'] = ((data['Team'] == data['Away Team']) & (data['Margin'] < 0))\
        | ((data['Team'] == data['Home Team']) & (data['Margin'] > 0))
    data = pd.get_dummies(data, columns=['Win'])
    
    # games with other than 6 votes (1+2+3) are removed
    games = data.groupby('GameID')['Brownlow Votes'].agg('sum')
    valid_gameIDs = games[np.where(games==6)[0]].index
    data = data[data['GameID'].isin(valid_gameIDs)]
    
    del(data['Day'])
    del(data['Date'])
    return data

# %%
clean = preprocess(data)

# %% [markdown]
# It shows that for each game, there are 22 players on each side. There is one special case where there are only 21 players in a team, which was Adelaide on 2003-03-30. Could just be a cut-off during scrapping?

# %%
for i, g in clean.groupby(['Team', 'GameID']):
    if g.shape[0] != 22:
        print(g.shape[0])
        print(g[['Team', 'GameID']].iloc[0])
# Out:
# 21
# Team                Adelaide
# GameID    2003-03-30Adelaide
# Name: 146586, dtype: object

# %%
# Splify by removing this game:
clean = clean[clean['GameID'] != '2003-03-30Adelaide']

# %%
train = clean[clean['Year'] <= 2015]
test = clean[clean['Year'] > 2015]
del(clean)
del(data)

# %%
print(train.shape)
print(test.shape)
# Out:
# (104940, 35)
# (33660, 35)

# %% [markdown]
# # Exploration

# %% [markdown]
# The number of games in `train` is 2333:

# %%
games = train.drop_duplicates(subset=['Home Team', 'Away Team', 'Margin'])[[
   'Season', 'Round', 'Home Team', 'Away Team',
       'Home Score', 'Away Score', 'Margin', 
]]
games
# Out:
#         Season Round               Home Team               Away Team  \
# 27412   2015.0    16              Gold Coast  Greater Western Sydney
# 27456   2015.0     4  Greater Western Sydney              Gold Coast
# 27500   2014.0     6              Gold Coast  Greater Western Sydney
# 27544   2013.0    23              Gold Coast  Greater Western Sydney
# 27588   2013.0     5  Greater Western Sydney              Gold Coast
# ...        ...   ...                     ...                     ...
# 146344  2003.0     6         North Melbourne                Adelaide
# 146388  2003.0     5                Adelaide           Port Adelaide
# 146432  2003.0     4                Adelaide              West Coast
# 146476  2003.0     3                  Sydney                Adelaide
# 146520  2003.0     2                St Kilda                Adelaide
#
#         Home Score  Away Score  Margin
# 27412           79          94     -15
# 27456          119          53      66
# 27500          134          94      40
# 27544          146          63      83
# 27588          104         148     -44
# ...            ...         ...     ...
# 146344          70         124     -54
# 146388          66          78     -12
# 146432         106          73      33
# 146476          76         103     -27
# 146520          99          91       8
#
# [2333 rows x 7 columns]

# %%
games[['Home Score', 'Away Score', 'Margin']].plot.hist(bins=20, alpha=0.5)

# %% [markdown]
# It shows that the Margin's mean is positive, meaning on average Home Score is higher than Away Score. Does this mean Home wins more than Away?

# %%
games['Home_won'] = games['Margin'] > 0
games['Home_won'].value_counts()
# Out:
# True     1323
# False    1010
# Name: Home_won, dtype: int64

# %% [markdown]
# The number of Home wins is 1.3 times the number of Away wins.

# %% [markdown]
# Next, let's show the distribution of performance indices:

# %%
import matplotlib.pyplot as plt


perf_idx = ['Disposals', 'Kicks', 'Marks',
       'Handballs', 'Goals', 'Behinds', 'Hitouts', 'Tackles', 'Rebounds',
       'Inside 50s', 'Clearances', 'Clangers', 'Frees For', 'Frees Against',
       'Contested Pos', 'Uncontested Pos', 'Contested Marks',
       'Marks Inside 50', 'One Percenters', 'Goal Assists', 'Brownlow Votes',
       'TOG', 'Win_False', 'Win_True']

def histogram(data, col):
    fig, ax = plt.subplots()
    ax.hist(data[col])
    ax.set_xlabel(col)
    plt.show()
    
for p in perf_idx:
    histogram(train, p)

# %% [markdown]
# We specifically care about the difference between the normal players and the voted ones:

# %%
import seaborn as sns
def scatter_by_votes(data, col):
    fig, ax = plt.subplots()
    sns.stripplot(train['Brownlow Votes'], train[col], jitter=0.2, size=2, ax=ax)
    plt.show()

# %%
for p in perf_idx:
    scatter_by_votes(train, p)

# %% [markdown]
# It shows that some of the most telling indices are:
# - TOG: No voted player plays under 40 minutes
# - Goals, Marks inside 50s, Contested Marks, Uncontested Pos, Contested Pos, Inside 50s, Handballs, Kicks, Disposals
#
# We can confirm these with a correlation matrix:

# %%
train.columns
# Out:
# Index(['Name', 'Team', 'Season', 'Round', 'Home Team', 'Away Team',
#        'Home Score', 'Away Score', 'Margin', 'Disposals', 'Kicks', 'Marks',
#        'Handballs', 'Goals', 'Behinds', 'Hitouts', 'Tackles', 'Rebounds',
#        'Inside 50s', 'Clearances', 'Clangers', 'Frees For', 'Frees Against',
#        'Contested Pos', 'Uncontested Pos', 'Contested Marks',
#        'Marks Inside 50', 'One Percenters', 'Goal Assists', 'Brownlow Votes',
#        'TOG', 'Year', 'GameID', 'Win_False', 'Win_True'],
#       dtype='object')

# %%
corr = train[['Disposals', 'Kicks', 'Marks',
       'Handballs', 'Goals', 'Behinds', 'Hitouts', 'Tackles', 'Rebounds',
       'Inside 50s', 'Clearances', 'Clangers', 'Frees For', 'Frees Against',
       'Contested Pos', 'Uncontested Pos', 'Contested Marks',
       'Marks Inside 50', 'One Percenters', 'Goal Assists', 'Brownlow Votes',
       'TOG', 'Win_True']].corr()

# %%
import numpy as np
fig = plt.figure(figsize=(18, 14))
c = plt.pcolor(corr)
plt.yticks(np.arange(0.5, len(corr.index), 1), corr.index)
plt.xticks(np.arange(0.5, len(corr.columns), 1), corr.columns, rotation=90)
fig.colorbar(c)

# %% [markdown]
# # Approach

# %% [markdown]
# It makes more sense to evaluate players in the scope of a game.\
# We can make an assumption that players are evaluated according to a certain linear formula of the performance indices, then we can normalize the score using softmax to pick the strongest ones.\
# Formally, a training example looks like this:
# ![image.png](attachment:image.png)

# %% [markdown]
# Where each row in $X$ corresponds to a player in that game, and the corresponding entry in $y$ is the number of votes he got.

# %% [markdown]
# For simplicity, I use `mse` as the loss function, although it seems that there should be a better one.\
# Because I treat this problem as a regression problem, entries in $y$ will be continuous.\
# As a final step after the training, I will round these entries to get the final predictions.\
# For this problem, because the vote tiers are skewed (more zeros than 1, 2, 3), I choose to evaluate recall percentage for each tier rather than overall accuracy.

# %%
features = ['Disposals', 'Kicks', 'Marks',
       'Handballs', 'Goals', 'Behinds', 'Hitouts', 'Tackles', 'Rebounds',
       'Inside 50s', 'Clearances', 'Clangers', 'Frees For', 'Frees Against',
       'Contested Pos', 'Uncontested Pos', 'Contested Marks',
       'Marks Inside 50', 'One Percenters', 'Goal Assists',
       'TOG', 'Win_False', 'Win_True']
n_features = len(features)

BATCH_SIZE = 32
val_split = .3 # Split 30% for validation from train

# %%
import tensorflow as tf

def make_tfds(data, features=features, split=None):
    """
    For each gameID, stack all the players to get a 44xm matrix
    """
            
    data_x, data_y = [],[]
    for i, gameid in enumerate(data['GameID'].unique()):
        game = data[data['GameID']==gameid]
        
        X = np.array(game[features])
        y = np.array(game['Brownlow Votes'])
        
        data_x.append(X)
        data_y.append(y)
        
    data_x = np.asarray(data_x) # shape ?, 44, n_features
    data_y = np.asarray(data_y)
    
    data_x = np.expand_dims(data_x, -1)
    
    if split != None: # create validation set
        split_point = int(split*data_x.shape[0])
        val_x = data_x[:split_point,:,:,:]
        val_y = data_y[:split_point,:]
        train_x = data_x[split_point:,:,:,:] 
        train_y = data_y[split_point:,]
        return tf.data.Dataset.from_tensor_slices((train_x, train_y)), \
                tf.data.Dataset.from_tensor_slices((val_x, val_y))
    
    return tf.data.Dataset.from_tensor_slices((data_x, data_y))

# %%
train_dataset, val_dataset = make_tfds(train, features, val_split)
test_dataset = make_tfds(test, features)

# %%
train_dataset = train_dataset.batch(BATCH_SIZE)
val_dataset = val_dataset.batch(BATCH_SIZE)
test_dataset = test_dataset.batch(BATCH_SIZE)

# %% [markdown]
# # Build and train a model

# %%
import tensorflow as tf
print(tf.__version__)
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, \
            Flatten, Conv2D, Dropout, Lambda
from keras.optimizers import SGD, Adam
# Out:
# 2.2.0-rc2

# %%
def get_model():
    model = Sequential()
    model.add(Conv2D(1, (1, n_features), activation='relu', kernel_initializer='he_uniform', input_shape=(44, n_features, 1)))
    model.add(Conv2D(1, (1, 1), kernel_initializer='he_uniform')),
    model.add(BatchNormalization())
    model.add(Conv2D(1, (1, 1), kernel_initializer='he_uniform')),
    model.add(BatchNormalization())
    model.add(Flatten())
    model.add(Dense(44))
    return model

# %% [markdown]
# Reasons behind this structure:
# - Use conv2D to reduce each row in $44\times m$ to a single number representing the overall performance of the player.
# - Another conv2D to increase the abstraction level, followed by a Batch Norm to avoid exploding/vanishing gradients.
# - Repeat.
# - Final dense layer allows indirect communication between nodes in conv2D, which may represents the comparision between them.

# %%
model = get_model()

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=.001),
              loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 44, 1, 1)          24
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 1, 1)          2
# _________________________________________________________________
# batch_normalization (BatchNo (None, 44, 1, 1)          4
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 44, 1, 1)          2
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 44, 1, 1)          4
# _________________________________________________________________
# flatten (Flatten)            (None, 44)                0
# _________________________________________________________________
# dense (Dense)                (None, 44)                1980
# =================================================================
# Total params: 2,016
# Trainable params: 2,012
# Non-trainable params: 4
# _________________________________________________________________

# %%
tf.keras.backend.clear_session()

# %%
model.evaluate(train_dataset) # loss before training
# Out:
# 53/53 [==============================] - 0s 2ms/step - loss: 8055.0547
# 8055.0546875

# %%
history = model.fit(train_dataset, validation_data=val_dataset, epochs=200)
# Out:
# Epoch 1/200
# 53/53 [==============================] - 0s 3ms/step - loss: 1.1038 - val_loss: 22.3363
# Epoch 2/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.7878 - val_loss: 3.6446
# Epoch 3/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.6007 - val_loss: 1.2573
# Epoch 4/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4865 - val_loss: 0.6997
# Epoch 5/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.4153 - val_loss: 0.5098
# Epoch 6/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3701 - val_loss: 0.4272
# Epoch 7/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3409 - val_loss: 0.3833
# Epoch 8/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3219 - val_loss: 0.3568
# Epoch 9/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3092 - val_loss: 0.3389
# Epoch 10/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.3005 - val_loss: 0.3248
# Epoch 11/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2941 - val_loss: 0.3128
# Epoch 12/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2891 - val_loss: 0.3026
# Epoch 13/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2845 - val_loss: 0.2979
# Epoch 14/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2800 - val_loss: 0.3059
# Epoch 15/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2749 - val_loss: 0.3376
# Epoch 16/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2691 - val_loss: 0.4023
# Epoch 17/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2624 - val_loss: 0.4934
# Epoch 18/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2549 - val_loss: 0.5814
# Epoch 19/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2474 - val_loss: 0.6060
# Epoch 20/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2411 - val_loss: 0.5181
# Epoch 21/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2367 - val_loss: 0.4124
# Epoch 22/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2282 - val_loss: 0.5383
# Epoch 23/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2079 - val_loss: 0.3406
# Epoch 24/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.2003 - val_loss: 0.2664
# Epoch 25/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1958 - val_loss: 0.2359
# Epoch 26/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1928 - val_loss: 0.2200
# Epoch 27/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1907 - val_loss: 0.2101
# Epoch 28/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1893 - val_loss: 0.2043
# Epoch 29/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1882 - val_loss: 0.2007
# Epoch 30/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1873 - val_loss: 0.1988
# Epoch 31/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1867 - val_loss: 0.1974
# Epoch 32/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1861 - val_loss: 0.1965
# Epoch 33/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1856 - val_loss: 0.1957
# Epoch 34/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1852 - val_loss: 0.1953
# Epoch 35/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1848 - val_loss: 0.1947
# Epoch 36/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1845 - val_loss: 0.1943
# Epoch 37/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1842 - val_loss: 0.1940
# Epoch 38/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1839 - val_loss: 0.1937
# Epoch 39/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1836 - val_loss: 0.1935
# Epoch 40/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1834 - val_loss: 0.1933
# Epoch 41/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1832 - val_loss: 0.1931
# Epoch 42/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1829 - val_loss: 0.1929
# Epoch 43/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1827 - val_loss: 0.1927
# Epoch 44/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1825 - val_loss: 0.1925
# Epoch 45/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1823 - val_loss: 0.1923
# Epoch 46/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1821 - val_loss: 0.1922
# Epoch 47/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1820 - val_loss: 0.1920
# Epoch 48/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1818 - val_loss: 0.1918
# Epoch 49/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1816 - val_loss: 0.1916
# Epoch 50/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1814 - val_loss: 0.1915
# Epoch 51/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1813 - val_loss: 0.1913
# Epoch 52/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1811 - val_loss: 0.1911
# Epoch 53/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1809 - val_loss: 0.1909
# Epoch 54/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1808 - val_loss: 0.1908
# Epoch 55/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1806 - val_loss: 0.1906
# Epoch 56/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1805 - val_loss: 0.1904
# Epoch 57/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1803 - val_loss: 0.1903
# Epoch 58/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1802 - val_loss: 0.1901
# Epoch 59/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1800 - val_loss: 0.1900
# Epoch 60/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1799 - val_loss: 0.1898
# Epoch 61/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1797 - val_loss: 0.1897
# Epoch 62/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1796 - val_loss: 0.1895
# Epoch 63/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1794 - val_loss: 0.1893
# Epoch 64/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1793 - val_loss: 0.1892
# Epoch 65/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1791 - val_loss: 0.1891
# Epoch 66/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1790 - val_loss: 0.1889
# Epoch 67/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1788 - val_loss: 0.1888
# Epoch 68/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1787 - val_loss: 0.1886
# Epoch 69/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1785 - val_loss: 0.1885
# Epoch 70/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1784 - val_loss: 0.1883
# Epoch 71/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1782 - val_loss: 0.1882
# Epoch 72/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1781 - val_loss: 0.1881
# Epoch 73/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1780 - val_loss: 0.1879
# Epoch 74/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1778 - val_loss: 0.1878
# Epoch 75/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1777 - val_loss: 0.1876
# Epoch 76/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1775 - val_loss: 0.1875
# Epoch 77/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1774 - val_loss: 0.1873
# Epoch 78/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1773 - val_loss: 0.1872
# Epoch 79/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1771 - val_loss: 0.1870
# Epoch 80/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1770 - val_loss: 0.1869
# Epoch 81/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1768 - val_loss: 0.1867
# Epoch 82/200
# 53/53 [==============================] - 0s 4ms/step - loss: 0.1767 - val_loss: 0.1865
# Epoch 83/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1766 - val_loss: 0.1864
# Epoch 84/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1764 - val_loss: 0.1863
# Epoch 85/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1763 - val_loss: 0.1861
# Epoch 86/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1761 - val_loss: 0.1860
# Epoch 87/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1760 - val_loss: 0.1858
# Epoch 88/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1759 - val_loss: 0.1857
# Epoch 89/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1757 - val_loss: 0.1855
# Epoch 90/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1756 - val_loss: 0.1854
# Epoch 91/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1755 - val_loss: 0.1853
# Epoch 92/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1753 - val_loss: 0.1851
# Epoch 93/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1752 - val_loss: 0.1849
# Epoch 94/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1751 - val_loss: 0.1848
# Epoch 95/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1750 - val_loss: 0.1848
# Epoch 96/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1748 - val_loss: 0.1847
# Epoch 97/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1747 - val_loss: 0.1844
# Epoch 98/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1746 - val_loss: 0.1844
# Epoch 99/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1744 - val_loss: 0.1841
# Epoch 100/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1743 - val_loss: 0.1841
# Epoch 101/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1742 - val_loss: 0.1838
# Epoch 102/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1741 - val_loss: 0.1837
# Epoch 103/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1739 - val_loss: 0.1835
# Epoch 104/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1738 - val_loss: 0.1833
# Epoch 105/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1737 - val_loss: 0.1833
# Epoch 106/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1736 - val_loss: 0.1832
# Epoch 107/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1735 - val_loss: 0.1831
# Epoch 108/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1733 - val_loss: 0.1829
# Epoch 109/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1732 - val_loss: 0.1828
# Epoch 110/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1731 - val_loss: 0.1825
# Epoch 111/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1731 - val_loss: 0.1823
# Epoch 112/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1730 - val_loss: 0.1822
# Epoch 113/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1728 - val_loss: 0.1820
# Epoch 114/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1727 - val_loss: 0.1819
# Epoch 115/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1726 - val_loss: 0.1818
# Epoch 116/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1725 - val_loss: 0.1817
# Epoch 117/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1724 - val_loss: 0.1815
# Epoch 118/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1723 - val_loss: 0.1814
# Epoch 119/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1722 - val_loss: 0.1813
# Epoch 120/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1721 - val_loss: 0.1812
# Epoch 121/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1720 - val_loss: 0.1811
# Epoch 122/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1719 - val_loss: 0.1809
# Epoch 123/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1718 - val_loss: 0.1808
# Epoch 124/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1717 - val_loss: 0.1808
# Epoch 125/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1717 - val_loss: 0.1807
# Epoch 126/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1716 - val_loss: 0.1806
# Epoch 127/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1715 - val_loss: 0.1805
# Epoch 128/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1714 - val_loss: 0.1806
# Epoch 129/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1714 - val_loss: 0.1804
# Epoch 130/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1713 - val_loss: 0.1803
# Epoch 131/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1712 - val_loss: 0.1802
# Epoch 132/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1712 - val_loss: 0.1801
# Epoch 133/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1711 - val_loss: 0.1801
# Epoch 134/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1711 - val_loss: 0.1800
# Epoch 135/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1710 - val_loss: 0.1800
# Epoch 136/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1710 - val_loss: 0.1800
# Epoch 137/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1709 - val_loss: 0.1799
# Epoch 138/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1709 - val_loss: 0.1800
# Epoch 139/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1709 - val_loss: 0.1799
# Epoch 140/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1708 - val_loss: 0.1798
# Epoch 141/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1708 - val_loss: 0.1798
# Epoch 142/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1708 - val_loss: 0.1797
# Epoch 143/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1708 - val_loss: 0.1797
# Epoch 144/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1707 - val_loss: 0.1797
# Epoch 145/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1707 - val_loss: 0.1796
# Epoch 146/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1707 - val_loss: 0.1796
# Epoch 147/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1706 - val_loss: 0.1796
# Epoch 148/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1706 - val_loss: 0.1796
# Epoch 149/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1706 - val_loss: 0.1795
# Epoch 150/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1706 - val_loss: 0.1795
# Epoch 151/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1705 - val_loss: 0.1795
# Epoch 152/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1705 - val_loss: 0.1794
# Epoch 153/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1705 - val_loss: 0.1794
# Epoch 154/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1705 - val_loss: 0.1794
# Epoch 155/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1705 - val_loss: 0.1794
# Epoch 156/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1705 - val_loss: 0.1794
# Epoch 157/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1704 - val_loss: 0.1794
# Epoch 158/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1704 - val_loss: 0.1794
# Epoch 159/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1704 - val_loss: 0.1794
# Epoch 160/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1704 - val_loss: 0.1794
# Epoch 161/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1704 - val_loss: 0.1793
# Epoch 162/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1703 - val_loss: 0.1793
# Epoch 163/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1793
# Epoch 164/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1795
# Epoch 165/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1795
# Epoch 166/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1795
# Epoch 167/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1703 - val_loss: 0.1795
# Epoch 168/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1795
# Epoch 169/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1703 - val_loss: 0.1800
# Epoch 170/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1798
# Epoch 171/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1703 - val_loss: 0.1799
# Epoch 172/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1798
# Epoch 173/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1799
# Epoch 174/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1798
# Epoch 175/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1798
# Epoch 176/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1798
# Epoch 177/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1798
# Epoch 178/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1798
# Epoch 179/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1798
# Epoch 180/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1703 - val_loss: 0.1798
# Epoch 181/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1798
# Epoch 182/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1703 - val_loss: 0.1798
# Epoch 183/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1702 - val_loss: 0.1798
# Epoch 184/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1702 - val_loss: 0.1798
# Epoch 185/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1702 - val_loss: 0.1798
# Epoch 186/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1702 - val_loss: 0.1798
# Epoch 187/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1702 - val_loss: 0.1798
# Epoch 188/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1702 - val_loss: 0.1798
# Epoch 189/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1702 - val_loss: 0.1798
# Epoch 190/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1702 - val_loss: 0.1797
# Epoch 191/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1702 - val_loss: 0.1797
# Epoch 192/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1702 - val_loss: 0.1797
# Epoch 193/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1702 - val_loss: 0.1797
# Epoch 194/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1702 - val_loss: 0.1797
# Epoch 195/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1702 - val_loss: 0.1797
# Epoch 196/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1702 - val_loss: 0.1797
# Epoch 197/200
# 53/53 [==============================] - 0s 2ms/step - loss: 0.1702 - val_loss: 0.1797
# Epoch 198/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1702 - val_loss: 0.1797
# Epoch 199/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1702 - val_loss: 0.1797
# Epoch 200/200
# 53/53 [==============================] - 0s 3ms/step - loss: 0.1702 - val_loss: 0.1797

# %%
import matplotlib.pyplot as plt

def summarize_diagnostics(history):
    # plot log of loss
    plt.plot(np.log(history.history['loss']), color='blue', label='train')
    plt.plot(np.log(history.history['val_loss']), color='orange', label='val')
    # plot accuracy
    plt.legend()
    plt.show()

# %%
summarize_diagnostics(history)

# %%
# Performance on val
pred = model.predict(val_dataset)

pred = pred.flatten()

truth = np.array(train['Brownlow Votes'])

def custom_eval(pred, true):
    
    count = {'1':0, '2':0, '3':0, '0':0}
    total = {'1':0, '2':0, '3':0, '0':0}
    
    for p,t in zip(list(pred), list(truth)):
        total[str(int(t))] += 1
        if round(p) == t:
            count[str(int(t))] += 1
            
    return [count[i]/total[i]*100 for i in ('1','2','3','0')]
                  
custom_eval(pred, truth)
# Out:
# [51.048951048951054, 16.223776223776223, 7.4125874125874125, 94.64438001023366]

# %%
# Performance on test
pred = model.predict(test_dataset)
pred = pred.flatten()

truth = np.array(test['Brownlow Votes'])

custom_eval(pred, truth)
# Out:
# [55.294117647058826, 24.313725490196077, 8.49673202614379, 93.53419416547106]

# %% [markdown]
# Summary performance on Test set:
# - Recall for `Brownlow=0` entries is 93.5%
# - Recall for `1` entries is 55.3%
# - Recall for `2` entries is 24.3%
# - Recall for `3` entries is 8.5%

# %% [markdown]
# # Space for improvement and experiment
# This problem is close to pixel level classification in computer vision, where we feed an image (a matrix) and obtain a matrix of the same dimension with each entry is the class for the corresponding pixel in the original matrix. We can take a look at that problem to see what kind of loss they use.\
# As far as I know, they often use binary masks in such problems. This may lead to complication.\
# Another approach is to use a different model.
